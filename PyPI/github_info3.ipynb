# %%
import json
import re
import pickle

import requests
import pandas as pd

# %% [markdown]
# ### 演示Github媒体API使用方法

# %%
github_path = 'https://api.github.com/repos/{owner}/{repo}'
Accept = 'application/vnd.github.v3.star+json'
github_app_res = requests.get(github_path.format(owner='ipython', repo='ipython'), headers={'Accept': Accept})
github_app_info = json.loads(github_app_res.text)
github_app_info
# Out:
# {'id': 658518,
#  'node_id': 'MDEwOlJlcG9zaXRvcnk2NTg1MTg=',
#  'name': 'ipython',
#  'full_name': 'ipython/ipython',
#  'private': False,
#  'owner': {'login': 'ipython',
#   'id': 230453,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIzMDQ1Mw==',
#   'avatar_url': 'https://avatars3.githubusercontent.com/u/230453?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ipython',
#   'html_url': 'https://github.com/ipython',
#   'followers_url': 'https://api.github.com/users/ipython/followers',
#   'following_url': 'https://api.github.com/users/ipython/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ipython/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ipython/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ipython/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ipython/orgs',
#   'repos_url': 'https://api.github.com/users/ipython/repos',
#   'events_url': 'https://api.github.com/users/ipython/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ipython/received_events',
#   'type': 'Organization',
#   'site_admin': False},
#  'html_url': 'https://github.com/ipython/ipython',
#  'description': 'Official repository for IPython itself. Other repos in the IPython organization contain things like the website, documentation builds, etc.',
#  'fork': False,
#  'url': 'https://api.github.com/repos/ipython/ipython',
#  'forks_url': 'https://api.github.com/repos/ipython/ipython/forks',
#  'keys_url': 'https://api.github.com/repos/ipython/ipython/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/ipython/ipython/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/ipython/ipython/teams',
#  'hooks_url': 'https://api.github.com/repos/ipython/ipython/hooks',
#  'issue_events_url': 'https://api.github.com/repos/ipython/ipython/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/ipython/ipython/events',
#  'assignees_url': 'https://api.github.com/repos/ipython/ipython/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/ipython/ipython/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/ipython/ipython/tags',
#  'blobs_url': 'https://api.github.com/repos/ipython/ipython/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/ipython/ipython/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/ipython/ipython/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/ipython/ipython/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/ipython/ipython/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/ipython/ipython/languages',
#  'stargazers_url': 'https://api.github.com/repos/ipython/ipython/stargazers',
#  'contributors_url': 'https://api.github.com/repos/ipython/ipython/contributors',
#  'subscribers_url': 'https://api.github.com/repos/ipython/ipython/subscribers',
#  'subscription_url': 'https://api.github.com/repos/ipython/ipython/subscription',
#  'commits_url': 'https://api.github.com/repos/ipython/ipython/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/ipython/ipython/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/ipython/ipython/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/ipython/ipython/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/ipython/ipython/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/ipython/ipython/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/ipython/ipython/merges',
#  'archive_url': 'https://api.github.com/repos/ipython/ipython/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/ipython/ipython/downloads',
#  'issues_url': 'https://api.github.com/repos/ipython/ipython/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/ipython/ipython/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/ipython/ipython/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/ipython/ipython/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/ipython/ipython/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/ipython/ipython/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/ipython/ipython/deployments',
#  'created_at': '2010-05-10T04:46:06Z',
#  'updated_at': '2020-11-23T06:49:16Z',
#  'pushed_at': '2020-11-21T06:40:47Z',
#  'git_url': 'git://github.com/ipython/ipython.git',
#  'ssh_url': 'git@github.com:ipython/ipython.git',
#  'clone_url': 'https://github.com/ipython/ipython.git',
#  'svn_url': 'https://github.com/ipython/ipython',
#  'homepage': 'https://ipython.readthedocs.org',
#  'size': 73938,
#  'stargazers_count': 14500,
#  'watchers_count': 14500,
#  'language': 'Python',
#  'has_issues': True,
#  'has_projects': False,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'forks_count': 4127,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 1427,
#  'license': {'key': 'other',
#   'name': 'Other',
#   'spdx_id': 'NOASSERTION',
#   'url': None,
#   'node_id': 'MDc6TGljZW5zZTA='},
#  'forks': 4127,
#  'open_issues': 1427,
#  'watchers': 14500,
#  'default_branch': 'master',
#  'temp_clone_token': None,
#  'organization': {'login': 'ipython',
#   'id': 230453,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIzMDQ1Mw==',
#   'avatar_url': 'https://avatars3.githubusercontent.com/u/230453?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ipython',
#   'html_url': 'https://github.com/ipython',
#   'followers_url': 'https://api.github.com/users/ipython/followers',
#   'following_url': 'https://api.github.com/users/ipython/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ipython/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ipython/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ipython/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ipython/orgs',
#   'repos_url': 'https://api.github.com/users/ipython/repos',
#   'events_url': 'https://api.github.com/users/ipython/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ipython/received_events',
#   'type': 'Organization',
#   'site_admin': False},
#  'network_count': 4127,
#  'subscribers_count': 818}

# %%
star_path = 'https://api.github.com/repos/{owner}/{repo}/stargazers'
Accept = 'application/vnd.github.v3.star+json'
star_res = requests.get(star_path.format(owner='ipython', repo='ipython'), headers={'Accept': Accept})
star_info = json.loads(star_res.text)
star_info
# Out:
# [{'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'kanzure',
#    'id': 101238,
#    'node_id': 'MDQ6VXNlcjEwMTIzOA==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/101238?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kanzure',
#    'html_url': 'https://github.com/kanzure',
#    'followers_url': 'https://api.github.com/users/kanzure/followers',
#    'following_url': 'https://api.github.com/users/kanzure/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kanzure/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kanzure/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kanzure/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kanzure/orgs',
#    'repos_url': 'https://api.github.com/users/kanzure/repos',
#    'events_url': 'https://api.github.com/users/kanzure/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kanzure/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'marvin',
#    'id': 557,
#    'node_id': 'MDQ6VXNlcjU1Nw==',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/557?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marvin',
#    'html_url': 'https://github.com/marvin',
#    'followers_url': 'https://api.github.com/users/marvin/followers',
#    'following_url': 'https://api.github.com/users/marvin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/marvin/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/marvin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/marvin/subscriptions',
#    'organizations_url': 'https://api.github.com/users/marvin/orgs',
#    'repos_url': 'https://api.github.com/users/marvin/repos',
#    'events_url': 'https://api.github.com/users/marvin/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/marvin/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'ludwig',
#    'id': 1056,
#    'node_id': 'MDQ6VXNlcjEwNTY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/1056?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ludwig',
#    'html_url': 'https://github.com/ludwig',
#    'followers_url': 'https://api.github.com/users/ludwig/followers',
#    'following_url': 'https://api.github.com/users/ludwig/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ludwig/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ludwig/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ludwig/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ludwig/orgs',
#    'repos_url': 'https://api.github.com/users/ludwig/repos',
#    'events_url': 'https://api.github.com/users/ludwig/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ludwig/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'frac',
#    'id': 1080,
#    'node_id': 'MDQ6VXNlcjEwODA=',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/1080?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/frac',
#    'html_url': 'https://github.com/frac',
#    'followers_url': 'https://api.github.com/users/frac/followers',
#    'following_url': 'https://api.github.com/users/frac/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/frac/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/frac/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/frac/subscriptions',
#    'organizations_url': 'https://api.github.com/users/frac/orgs',
#    'repos_url': 'https://api.github.com/users/frac/repos',
#    'events_url': 'https://api.github.com/users/frac/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/frac/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'zirpu',
#    'id': 1279,
#    'node_id': 'MDQ6VXNlcjEyNzk=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/1279?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zirpu',
#    'html_url': 'https://github.com/zirpu',
#    'followers_url': 'https://api.github.com/users/zirpu/followers',
#    'following_url': 'https://api.github.com/users/zirpu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/zirpu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/zirpu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/zirpu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/zirpu/orgs',
#    'repos_url': 'https://api.github.com/users/zirpu/repos',
#    'events_url': 'https://api.github.com/users/zirpu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/zirpu/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'charlenopires',
#    'id': 1365,
#    'node_id': 'MDQ6VXNlcjEzNjU=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/1365?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/charlenopires',
#    'html_url': 'https://github.com/charlenopires',
#    'followers_url': 'https://api.github.com/users/charlenopires/followers',
#    'following_url': 'https://api.github.com/users/charlenopires/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/charlenopires/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/charlenopires/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/charlenopires/subscriptions',
#    'organizations_url': 'https://api.github.com/users/charlenopires/orgs',
#    'repos_url': 'https://api.github.com/users/charlenopires/repos',
#    'events_url': 'https://api.github.com/users/charlenopires/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/charlenopires/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'ask',
#    'id': 1558,
#    'node_id': 'MDQ6VXNlcjE1NTg=',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/1558?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ask',
#    'html_url': 'https://github.com/ask',
#    'followers_url': 'https://api.github.com/users/ask/followers',
#    'following_url': 'https://api.github.com/users/ask/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ask/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ask/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ask/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ask/orgs',
#    'repos_url': 'https://api.github.com/users/ask/repos',
#    'events_url': 'https://api.github.com/users/ask/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ask/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'cw',
#    'id': 1692,
#    'node_id': 'MDQ6VXNlcjE2OTI=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/1692?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cw',
#    'html_url': 'https://github.com/cw',
#    'followers_url': 'https://api.github.com/users/cw/followers',
#    'following_url': 'https://api.github.com/users/cw/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cw/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cw/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cw/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cw/orgs',
#    'repos_url': 'https://api.github.com/users/cw/repos',
#    'events_url': 'https://api.github.com/users/cw/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cw/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'jiahao',
#    'id': 1732,
#    'node_id': 'MDQ6VXNlcjE3MzI=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/1732?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jiahao',
#    'html_url': 'https://github.com/jiahao',
#    'followers_url': 'https://api.github.com/users/jiahao/followers',
#    'following_url': 'https://api.github.com/users/jiahao/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jiahao/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jiahao/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jiahao/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jiahao/orgs',
#    'repos_url': 'https://api.github.com/users/jiahao/repos',
#    'events_url': 'https://api.github.com/users/jiahao/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jiahao/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'bmabey',
#    'id': 1837,
#    'node_id': 'MDQ6VXNlcjE4Mzc=',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/1837?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bmabey',
#    'html_url': 'https://github.com/bmabey',
#    'followers_url': 'https://api.github.com/users/bmabey/followers',
#    'following_url': 'https://api.github.com/users/bmabey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bmabey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bmabey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bmabey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bmabey/orgs',
#    'repos_url': 'https://api.github.com/users/bmabey/repos',
#    'events_url': 'https://api.github.com/users/bmabey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bmabey/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'abisani',
#    'id': 1954,
#    'node_id': 'MDQ6VXNlcjE5NTQ=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/1954?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abisani',
#    'html_url': 'https://github.com/abisani',
#    'followers_url': 'https://api.github.com/users/abisani/followers',
#    'following_url': 'https://api.github.com/users/abisani/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/abisani/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/abisani/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/abisani/subscriptions',
#    'organizations_url': 'https://api.github.com/users/abisani/orgs',
#    'repos_url': 'https://api.github.com/users/abisani/repos',
#    'events_url': 'https://api.github.com/users/abisani/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/abisani/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'alfakini',
#    'id': 4171,
#    'node_id': 'MDQ6VXNlcjQxNzE=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/4171?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alfakini',
#    'html_url': 'https://github.com/alfakini',
#    'followers_url': 'https://api.github.com/users/alfakini/followers',
#    'following_url': 'https://api.github.com/users/alfakini/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alfakini/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alfakini/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alfakini/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alfakini/orgs',
#    'repos_url': 'https://api.github.com/users/alfakini/repos',
#    'events_url': 'https://api.github.com/users/alfakini/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alfakini/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'tswicegood',
#    'id': 4328,
#    'node_id': 'MDQ6VXNlcjQzMjg=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/4328?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tswicegood',
#    'html_url': 'https://github.com/tswicegood',
#    'followers_url': 'https://api.github.com/users/tswicegood/followers',
#    'following_url': 'https://api.github.com/users/tswicegood/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tswicegood/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tswicegood/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tswicegood/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tswicegood/orgs',
#    'repos_url': 'https://api.github.com/users/tswicegood/repos',
#    'events_url': 'https://api.github.com/users/tswicegood/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tswicegood/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'yeliu84',
#    'id': 4915,
#    'node_id': 'MDQ6VXNlcjQ5MTU=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/4915?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yeliu84',
#    'html_url': 'https://github.com/yeliu84',
#    'followers_url': 'https://api.github.com/users/yeliu84/followers',
#    'following_url': 'https://api.github.com/users/yeliu84/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yeliu84/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yeliu84/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yeliu84/subscriptions',
#    'organizations_url': 'https://api.github.com/users/yeliu84/orgs',
#    'repos_url': 'https://api.github.com/users/yeliu84/repos',
#    'events_url': 'https://api.github.com/users/yeliu84/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/yeliu84/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'lebigot',
#    'id': 5793,
#    'node_id': 'MDQ6VXNlcjU3OTM=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/5793?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lebigot',
#    'html_url': 'https://github.com/lebigot',
#    'followers_url': 'https://api.github.com/users/lebigot/followers',
#    'following_url': 'https://api.github.com/users/lebigot/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lebigot/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lebigot/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lebigot/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lebigot/orgs',
#    'repos_url': 'https://api.github.com/users/lebigot/repos',
#    'events_url': 'https://api.github.com/users/lebigot/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lebigot/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'mmkassem',
#    'id': 6854,
#    'node_id': 'MDQ6VXNlcjY4NTQ=',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/6854?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmkassem',
#    'html_url': 'https://github.com/mmkassem',
#    'followers_url': 'https://api.github.com/users/mmkassem/followers',
#    'following_url': 'https://api.github.com/users/mmkassem/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mmkassem/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mmkassem/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mmkassem/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mmkassem/orgs',
#    'repos_url': 'https://api.github.com/users/mmkassem/repos',
#    'events_url': 'https://api.github.com/users/mmkassem/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mmkassem/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'kirubakaran',
#    'id': 7503,
#    'node_id': 'MDQ6VXNlcjc1MDM=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/7503?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kirubakaran',
#    'html_url': 'https://github.com/kirubakaran',
#    'followers_url': 'https://api.github.com/users/kirubakaran/followers',
#    'following_url': 'https://api.github.com/users/kirubakaran/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kirubakaran/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kirubakaran/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kirubakaran/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kirubakaran/orgs',
#    'repos_url': 'https://api.github.com/users/kirubakaran/repos',
#    'events_url': 'https://api.github.com/users/kirubakaran/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kirubakaran/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'shiva',
#    'id': 7524,
#    'node_id': 'MDQ6VXNlcjc1MjQ=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/7524?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shiva',
#    'html_url': 'https://github.com/shiva',
#    'followers_url': 'https://api.github.com/users/shiva/followers',
#    'following_url': 'https://api.github.com/users/shiva/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shiva/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shiva/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shiva/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shiva/orgs',
#    'repos_url': 'https://api.github.com/users/shiva/repos',
#    'events_url': 'https://api.github.com/users/shiva/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shiva/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'lmacken',
#    'id': 9980,
#    'node_id': 'MDQ6VXNlcjk5ODA=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/9980?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lmacken',
#    'html_url': 'https://github.com/lmacken',
#    'followers_url': 'https://api.github.com/users/lmacken/followers',
#    'following_url': 'https://api.github.com/users/lmacken/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lmacken/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lmacken/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lmacken/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lmacken/orgs',
#    'repos_url': 'https://api.github.com/users/lmacken/repos',
#    'events_url': 'https://api.github.com/users/lmacken/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lmacken/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'madhusudancs',
#    'id': 10183,
#    'node_id': 'MDQ6VXNlcjEwMTgz',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/10183?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/madhusudancs',
#    'html_url': 'https://github.com/madhusudancs',
#    'followers_url': 'https://api.github.com/users/madhusudancs/followers',
#    'following_url': 'https://api.github.com/users/madhusudancs/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/madhusudancs/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/madhusudancs/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/madhusudancs/subscriptions',
#    'organizations_url': 'https://api.github.com/users/madhusudancs/orgs',
#    'repos_url': 'https://api.github.com/users/madhusudancs/repos',
#    'events_url': 'https://api.github.com/users/madhusudancs/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/madhusudancs/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'cbess',
#    'id': 10981,
#    'node_id': 'MDQ6VXNlcjEwOTgx',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/10981?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbess',
#    'html_url': 'https://github.com/cbess',
#    'followers_url': 'https://api.github.com/users/cbess/followers',
#    'following_url': 'https://api.github.com/users/cbess/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbess/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbess/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbess/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbess/orgs',
#    'repos_url': 'https://api.github.com/users/cbess/repos',
#    'events_url': 'https://api.github.com/users/cbess/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbess/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'jpwatts',
#    'id': 11224,
#    'node_id': 'MDQ6VXNlcjExMjI0',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/11224?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jpwatts',
#    'html_url': 'https://github.com/jpwatts',
#    'followers_url': 'https://api.github.com/users/jpwatts/followers',
#    'following_url': 'https://api.github.com/users/jpwatts/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jpwatts/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jpwatts/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jpwatts/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jpwatts/orgs',
#    'repos_url': 'https://api.github.com/users/jpwatts/repos',
#    'events_url': 'https://api.github.com/users/jpwatts/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jpwatts/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'kozo2',
#    'id': 12192,
#    'node_id': 'MDQ6VXNlcjEyMTky',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/12192?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kozo2',
#    'html_url': 'https://github.com/kozo2',
#    'followers_url': 'https://api.github.com/users/kozo2/followers',
#    'following_url': 'https://api.github.com/users/kozo2/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kozo2/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kozo2/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kozo2/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kozo2/orgs',
#    'repos_url': 'https://api.github.com/users/kozo2/repos',
#    'events_url': 'https://api.github.com/users/kozo2/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kozo2/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'jonbaer',
#    'id': 13155,
#    'node_id': 'MDQ6VXNlcjEzMTU1',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/13155?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jonbaer',
#    'html_url': 'https://github.com/jonbaer',
#    'followers_url': 'https://api.github.com/users/jonbaer/followers',
#    'following_url': 'https://api.github.com/users/jonbaer/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jonbaer/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jonbaer/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jonbaer/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jonbaer/orgs',
#    'repos_url': 'https://api.github.com/users/jonbaer/repos',
#    'events_url': 'https://api.github.com/users/jonbaer/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jonbaer/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'ggtr1138',
#    'id': 13363,
#    'node_id': 'MDQ6VXNlcjEzMzYz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/13363?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ggtr1138',
#    'html_url': 'https://github.com/ggtr1138',
#    'followers_url': 'https://api.github.com/users/ggtr1138/followers',
#    'following_url': 'https://api.github.com/users/ggtr1138/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ggtr1138/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ggtr1138/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ggtr1138/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ggtr1138/orgs',
#    'repos_url': 'https://api.github.com/users/ggtr1138/repos',
#    'events_url': 'https://api.github.com/users/ggtr1138/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ggtr1138/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'ejs',
#    'id': 13847,
#    'node_id': 'MDQ6VXNlcjEzODQ3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/13847?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ejs',
#    'html_url': 'https://github.com/ejs',
#    'followers_url': 'https://api.github.com/users/ejs/followers',
#    'following_url': 'https://api.github.com/users/ejs/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ejs/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ejs/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ejs/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ejs/orgs',
#    'repos_url': 'https://api.github.com/users/ejs/repos',
#    'events_url': 'https://api.github.com/users/ejs/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ejs/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'tylerw',
#    'id': 14808,
#    'node_id': 'MDQ6VXNlcjE0ODA4',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/14808?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tylerw',
#    'html_url': 'https://github.com/tylerw',
#    'followers_url': 'https://api.github.com/users/tylerw/followers',
#    'following_url': 'https://api.github.com/users/tylerw/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tylerw/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tylerw/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tylerw/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tylerw/orgs',
#    'repos_url': 'https://api.github.com/users/tylerw/repos',
#    'events_url': 'https://api.github.com/users/tylerw/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tylerw/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'hammer',
#    'id': 15233,
#    'node_id': 'MDQ6VXNlcjE1MjMz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/15233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hammer',
#    'html_url': 'https://github.com/hammer',
#    'followers_url': 'https://api.github.com/users/hammer/followers',
#    'following_url': 'https://api.github.com/users/hammer/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hammer/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hammer/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hammer/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hammer/orgs',
#    'repos_url': 'https://api.github.com/users/hammer/repos',
#    'events_url': 'https://api.github.com/users/hammer/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hammer/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'takano32',
#    'id': 16088,
#    'node_id': 'MDQ6VXNlcjE2MDg4',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/16088?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/takano32',
#    'html_url': 'https://github.com/takano32',
#    'followers_url': 'https://api.github.com/users/takano32/followers',
#    'following_url': 'https://api.github.com/users/takano32/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/takano32/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/takano32/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/takano32/subscriptions',
#    'organizations_url': 'https://api.github.com/users/takano32/orgs',
#    'repos_url': 'https://api.github.com/users/takano32/repos',
#    'events_url': 'https://api.github.com/users/takano32/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/takano32/received_events',
#    'type': 'User',
#    'site_admin': False}},
#  {'starred_at': '2010-05-10T04:46:06Z',
#   'user': {'login': 'epitron',
#    'id': 16409,
#    'node_id': 'MDQ6VXNlcjE2NDA5',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/16409?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/epitron',
#    'html_url': 'https://github.com/epitron',
#    'followers_url': 'https://api.github.com/users/epitron/followers',
#    'following_url': 'https://api.github.com/users/epitron/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/epitron/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/epitron/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/epitron/subscriptions',
#    'organizations_url': 'https://api.github.com/users/epitron/orgs',
#    'repos_url': 'https://api.github.com/users/epitron/repos',
#    'events_url': 'https://api.github.com/users/epitron/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/epitron/received_events',
#    'type': 'User',
#    'site_admin': False}}]

# %%
star_res.headers['link']
# Out:
# '<https://api.github.com/repositories/658518/stargazers?page=2>; rel="next", <https://api.github.com/repositories/658518/stargazers?page=484>; rel="last"'

# %% [markdown]
# ### 开始爬取

# %%
df = pd.read_pickle('pypi_json.pkl')

# %%
for i in df.github:
    if i not in (None, True, False):
        print(type(i))
        break
# Out:
# <class 'tuple'>

# %%
def get_star_time(df):
    star_path = 'https://api.github.com/repos/{}/{}/stargazers'
    token = 'a778aeacfadcaae486f97b8c9a560121b4b44711'
    Accept = 'application/vnd.github.v3.star+json'
    star_infos = []
    for package_name, aha in df.github.groupby(level=0):
        for i in aha.values[::-1]:
            if i not in (None, True, False):
                star_res = requests.get(star_path.format(*i), headers={'Accept': Accept, 'Authorization': 'token ' + token})
                msg = json.loads(star_res.text)
                try:
                    star_infos.append(dict(
                        _id=package_name,
                        star_time=[i['starred_at'] for i in msg]
                    ))
                except TypeError:
                    if msg['message'] == 'Not Found':
                        continue
                    elif 'rate limit' in msg['message']:
                        return star_infos
                    else:
                        print(msg)
                        return star_infos
                else:
                    break
    return star_infos

# %%
packages = sorted(set(list(zip(*df.index))[0]))

# %%
3e4
# Out:
# 30000.0

# %%
goal = int(3e4)
star_infos = get_star_time(df.loc[packages[packages.index(star_infos[-1]['_id']):goal]])

# %%
packages.index(star_infos[-1]['_id'])
# Out:
# 20813

# %%
with open(f"./STAR/star_info_20000-{packages.index(star_infos[-1]['_id'])}", 'wb') as f:
    pickle.dump(star_infos, f, pickle.HIGHEST_PROTOCOL)

# %%
len(star_infos)
# Out:
# 40

# %%
star_path = 'https://api.github.com/repos/{}/{}/stargazers'
token = 'a778aeacfadcaae486f97b8c9a560121b4b44711'
Accept = 'application/vnd.github.v3.star+json'
i = 'ipython', 'ipython'
res = requests.get(star_path.format(*i), headers={'Accept': Accept, 'Authorization': 'token ' + token})

# %%
res.headers['X-RateLimit-Remaining']
# Out:
# '4268'
